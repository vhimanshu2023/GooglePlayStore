# %% [markdown]
# #### Copyright 2017 Google LLC.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('googleplaystore.csv')

# %% [markdown]
# Top 5 Rows of The Dataset

# %%
print(df.head())
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
#  Last 3 Rows of The Dataset

# %%
print(df.tail())
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %% [markdown]
# Information About Our Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# Shape of the dataset

# %%
print('Numbers of rows',df.shape[0])
print('Numbers of columns',df.shape[1])
# Out:
# Numbers of rows 10841
# Numbers of columns 13

# %% [markdown]
#  Overall Statistics About The Dataframe

# %%
df.describe(include='all')
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %% [markdown]
# # **Deal with missing value and some other values**

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
ndf = df.isnull()
sns.heatmap(ndf)
plt.show()

# %%
ndf1 = df.notnull()
sns.heatmap(ndf1)
plt.show()

# %%
df.fillna(
    {
    'Rating' : 0.0,
    'Type' : df['Type'].fillna(method='ffill'),
    'Content Rating' : df['Content Rating'].fillna(method='ffill'),
    'Current Ver' : df['Current Ver'].fillna(method='ffill'),
    'Android Ver' : df['Android Ver'].fillna(method='ffill')
    }
)
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df['Size'] = df['Size'].str.replace('M','')
df['Installs'] = df['Installs'].str.replace('+','')
df['Installs'] = df['Installs'].str.replace(',','')
# Out:
# <ipython-input-6-38e802008f0d>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Installs'] = df['Installs'].str.replace('+','')

# %%
df['Rating'].sort_values(ascending=False)
df.drop([10472],inplace=True)

# %% [markdown]
#  Total Number of App Titles Contain Astrology

# %%
len(df.loc[df['App'].str.contains('Astrology')])
# Out:
# 3

# %% [markdown]
# Total Number of Unique Category

# %%
len(df['Category'].unique())
# Out:
# 34

# %% [markdown]
# Highest Avg. Rating

# %%
df.groupby('Category')['Rating'].mean().max()
# Out:
# 19.0

# %% [markdown]
# Total Number of App having 5 Star Rating

# %%
len(df.loc[df['Rating'] == 5])
# Out:
# 274

# %% [markdown]
#  Average Value of Reviews

# %%
df['Reviews'] = df['Reviews'].str.replace('M','')

# %%
df['Reviews'] = df['Reviews'].astype(float)

# %%
df['Reviews'].dtype
# Out:
# dtype('float64')

# %%
df['Reviews'].mean()
# Out:
# 444111.9265750392

# %% [markdown]
# Total Number of Free and Paid Apps

# %%
df.groupby('Type')['Type'].count()
# Out:
# Type
# 0           1
# Free    10039
# Paid      800
# Name: Type, dtype: int64

# %% [markdown]
# App Has Maximum Reviews?

# %%
mx = df['Reviews'].max()
df.loc[df['Reviews'] == mx]['App']
# Out:
# 2544    Facebook
# Name: App, dtype: object

# %% [markdown]
# Top 5 Apps Having Highest Reviews

# %%
df[['App','Reviews']].sort_values('Reviews',ascending = False).head().reset_index(drop=True)
# Out:
#                   App     Reviews
# 0            Facebook  78158306.0
# 1            Facebook  78128208.0
# 2  WhatsApp Messenger  69119316.0
# 3  WhatsApp Messenger  69119316.0
# 4  WhatsApp Messenger  69109672.0

# %% [markdown]
# Average Rating of Free and Paid Apps

# %%
df.groupby('Type')['Rating'].mean()
# Out:
# Type
# Free    4.186203
# Paid    4.266615
# Name: Rating, dtype: float64

# %% [markdown]
# Top  5 Apps Having Maximum Installs

# %%
idx = df['Installs'].sort_values(ascending=False).head().index
df.iloc[idx,:1]
# Out:
#                                            App
# 10472  Life Made WI-Fi Touchscreen Photo Frame
# 1655                          Candy Crush Saga
# 3870                                  Snapchat
# 1759                              Temple Run 2
# 3879                                       Pou

# %% [markdown]
# # Visualization

# %%
sns.relplot(data=df ,x='Rating',y='Reviews',kind='line',hue='Type')
plt.grid()
plt.show()

# %%
sns.countplot(data=df ,x='Rating')
plt.show()

# %%
sns.countplot(data=df ,x='Rating',hue='Type')
plt.show()

# %%
sns.pairplot(data=df,hue='Type')
plt.show()

# %%
cnt = df.groupby('Category').count().reset_index()
sns.relplot(x=cnt['Category'],y=cnt['App'],data=cnt,hue='Type')
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
df['Price'] = df['Price'].str.replace('$','')
df['Price'] = df['Price'].astype('float')
df['Price'].dtype
# Out:
# dtype('float64')

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
sns.countplot(data=df,x='Category',hue='Type')
plt.xticks(rotation=90)
plt.show()

# %%
sns.pairplot(data=df)
plt.show()
